# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/tb_cat_autopart_202410211607.csv")
df
# Out:
#          id  id_record_status  id_company_variation  id_product  \
# 0     18330                 1                    97       14109
# 1     18331                 1                    97       14109
# 2     18332                 1                    97       14109
# 3     18333                 1                    97       14109
# 4     18334                 1                    97       14109
# ...     ...               ...                   ...         ...
# 9995  23022                 1                    97       14253
# 9996  23023                 1                    97       14253
# 9997  23024                 1                    97       14253
# 9998  23025                 1                    97       14253
# 9999  23026                 1                    97       14253
#
#       id_cat_autopart_make  id_cat_autopart_model  \
# 0                     40.0                  479.0
# 1                     40.0                  479.0
# 2                     40.0                  479.0
# 3                     40.0                  479.0
# 4                     40.0                  480.0
# ...                    ...                    ...
# 9995                  50.0                  591.0
# 9996                  50.0                  591.0
# 9997                  50.0                  592.0
# 9998                  50.0                  593.0
# 9999                  50.0                  593.0
#
#       id_cat_autopart_engine_type  id_cat_autopart_engine_size  \
# 0                           684.0                        171.0
# 1                           685.0                        172.0
# 2                           686.0                        172.0
# 3                           687.0                        171.0
# 4                           684.0                        171.0
# ...                           ...                          ...
# 9995                       1149.0                        360.0
# 9996                       1150.0                        360.0
# 9997                       1148.0                        361.0
# 9998                       1149.0                        362.0
# 9999                       1149.0                        361.0
#
#       id_cat_autopart_notes  id_subscription  year_from  year_to  \
# 0                       2.0              105     2013.0      NaN
# 1                       2.0              105     2013.0      NaN
# 2                       2.0              105     2013.0      NaN
# 3                       2.0              105     2013.0      NaN
# 4                       2.0              105     2013.0      NaN
# ...                     ...              ...        ...      ...
# 9995                    2.0              105     2011.0      NaN
# 9996                    2.0              105     2011.0      NaN
# 9997                    2.0              105     2011.0      NaN
# 9998                    2.0              105     2011.0      NaN
# 9999                    2.0              105     2011.0      NaN
#
#                   create_date  update_date  delete_date
# 0     2018-03-16 21:23:41.000          NaN          NaN
# 1     2018-03-16 21:23:41.000          NaN          NaN
# 2     2018-03-16 21:23:41.000          NaN          NaN
# 3     2018-03-16 21:23:41.000          NaN          NaN
# 4     2018-03-16 21:23:41.000          NaN          NaN
# ...                       ...          ...          ...
# 9995  2018-03-16 21:24:21.000          NaN          NaN
# 9996  2018-03-16 21:24:21.000          NaN          NaN
# 9997  2018-03-16 21:24:21.000          NaN          NaN
# 9998  2018-03-16 21:24:21.000          NaN          NaN
# 9999  2018-03-16 21:24:21.000          NaN          NaN
#
# [10000 rows x 15 columns]

# %%
# Convertir la columna a tipo datetime, asumiendo que es el año
df['year_from'] = pd.to_datetime(df['year_from'], format='%Y')

# Extraer el año como entero
df['year_from'] = df['year_from'].dt.year

# %%
df.dtypes
# Out:
# id                               int64
# id_record_status                 int64
# id_company_variation             int64
# id_product                       int64
# id_cat_autopart_make           float64
# id_cat_autopart_model          float64
# id_cat_autopart_engine_type    float64
# id_cat_autopart_engine_size    float64
# id_cat_autopart_notes          float64
# id_subscription                  int64
# year_from                      float64
# year_to                        float64
# create_date                     object
# update_date                    float64
# delete_date                    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                                 0
# id_record_status                   0
# id_company_variation               0
# id_product                         0
# id_cat_autopart_make             651
# id_cat_autopart_model            651
# id_cat_autopart_engine_type     5053
# id_cat_autopart_engine_size     5053
# id_cat_autopart_notes           5053
# id_subscription                    0
# year_from                        652
# year_to                        10000
# create_date                        0
# update_date                    10000
# delete_date                    10000
# dtype: int64

# %%
df_drop  = ['delete_date','update_date','year_to']
df_clean = df.drop(df_drop, axis = 1)
df_clean.head()
# Out:
#       id  id_record_status  id_company_variation  id_product  \
# 0  18330                 1                    97       14109
# 1  18331                 1                    97       14109
# 2  18332                 1                    97       14109
# 3  18333                 1                    97       14109
# 4  18334                 1                    97       14109
#
#    id_cat_autopart_make  id_cat_autopart_model  id_cat_autopart_engine_type  \
# 0                  40.0                  479.0                        684.0
# 1                  40.0                  479.0                        685.0
# 2                  40.0                  479.0                        686.0
# 3                  40.0                  479.0                        687.0
# 4                  40.0                  480.0                        684.0
#
#    id_cat_autopart_engine_size  id_cat_autopart_notes  id_subscription  \
# 0                        171.0                    2.0              105
# 1                        172.0                    2.0              105
# 2                        172.0                    2.0              105
# 3                        171.0                    2.0              105
# 4                        171.0                    2.0              105
#
#    year_from              create_date
# 0     2013.0  2018-03-16 21:23:41.000
# 1     2013.0  2018-03-16 21:23:41.000
# 2     2013.0  2018-03-16 21:23:41.000
# 3     2013.0  2018-03-16 21:23:41.000
# 4     2013.0  2018-03-16 21:23:41.000

# %%
df_clean
# Out:
#          id  id_record_status  id_company_variation  id_product  \
# 0     18330                 1                    97       14109
# 1     18331                 1                    97       14109
# 2     18332                 1                    97       14109
# 3     18333                 1                    97       14109
# 4     18334                 1                    97       14109
# ...     ...               ...                   ...         ...
# 9995  23022                 1                    97       14253
# 9996  23023                 1                    97       14253
# 9997  23024                 1                    97       14253
# 9998  23025                 1                    97       14253
# 9999  23026                 1                    97       14253
#
#       id_cat_autopart_make  id_cat_autopart_model  \
# 0                     40.0                  479.0
# 1                     40.0                  479.0
# 2                     40.0                  479.0
# 3                     40.0                  479.0
# 4                     40.0                  480.0
# ...                    ...                    ...
# 9995                  50.0                  591.0
# 9996                  50.0                  591.0
# 9997                  50.0                  592.0
# 9998                  50.0                  593.0
# 9999                  50.0                  593.0
#
#       id_cat_autopart_engine_type  id_cat_autopart_engine_size  \
# 0                           684.0                        171.0
# 1                           685.0                        172.0
# 2                           686.0                        172.0
# 3                           687.0                        171.0
# 4                           684.0                        171.0
# ...                           ...                          ...
# 9995                       1149.0                        360.0
# 9996                       1150.0                        360.0
# 9997                       1148.0                        361.0
# 9998                       1149.0                        362.0
# 9999                       1149.0                        361.0
#
#       id_cat_autopart_notes  id_subscription  year_from  \
# 0                       2.0              105     2013.0
# 1                       2.0              105     2013.0
# 2                       2.0              105     2013.0
# 3                       2.0              105     2013.0
# 4                       2.0              105     2013.0
# ...                     ...              ...        ...
# 9995                    2.0              105     2011.0
# 9996                    2.0              105     2011.0
# 9997                    2.0              105     2011.0
# 9998                    2.0              105     2011.0
# 9999                    2.0              105     2011.0
#
#                   create_date
# 0     2018-03-16 21:23:41.000
# 1     2018-03-16 21:23:41.000
# 2     2018-03-16 21:23:41.000
# 3     2018-03-16 21:23:41.000
# 4     2018-03-16 21:23:41.000
# ...                       ...
# 9995  2018-03-16 21:24:21.000
# 9996  2018-03-16 21:24:21.000
# 9997  2018-03-16 21:24:21.000
# 9998  2018-03-16 21:24:21.000
# 9999  2018-03-16 21:24:21.000
#
# [10000 rows x 12 columns]

# %%
df_clean.dtypes
# Out:
# id                               int64
# id_record_status                 int64
# id_company_variation             int64
# id_product                       int64
# id_cat_autopart_make           float64
# id_cat_autopart_model          float64
# id_cat_autopart_engine_type    float64
# id_cat_autopart_engine_size    float64
# id_cat_autopart_notes          float64
# id_subscription                  int64
# year_from                      float64
# create_date                     object
# dtype: object

# %%
#Se le aplica interpolacion al formato fecha
df_clean['year_from'].fillna(method='bfill', inplace=True)
# Out:
# <ipython-input-9-b37110f05596>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['year_from'].fillna(method='bfill', inplace=True)
# <ipython-input-9-b37110f05596>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_clean['year_from'].fillna(method='bfill', inplace=True)

# %%
#Cambiamos el year_from a entero
df_clean['year_from'] = df_clean['year_from'].astype(int)
df_clean.head()
# Out:
#       id  id_record_status  id_company_variation  id_product  \
# 0  18330                 1                    97       14109
# 1  18331                 1                    97       14109
# 2  18332                 1                    97       14109
# 3  18333                 1                    97       14109
# 4  18334                 1                    97       14109
#
#    id_cat_autopart_make  id_cat_autopart_model  id_cat_autopart_engine_type  \
# 0                  40.0                  479.0                        684.0
# 1                  40.0                  479.0                        685.0
# 2                  40.0                  479.0                        686.0
# 3                  40.0                  479.0                        687.0
# 4                  40.0                  480.0                        684.0
#
#    id_cat_autopart_engine_size  id_cat_autopart_notes  id_subscription  \
# 0                        171.0                    2.0              105
# 1                        172.0                    2.0              105
# 2                        172.0                    2.0              105
# 3                        171.0                    2.0              105
# 4                        171.0                    2.0              105
#
#    year_from              create_date
# 0       2013  2018-03-16 21:23:41.000
# 1       2013  2018-03-16 21:23:41.000
# 2       2013  2018-03-16 21:23:41.000
# 3       2013  2018-03-16 21:23:41.000
# 4       2013  2018-03-16 21:23:41.000

# %%
#convertir fechas a formato %d/%m/%Y y mantener los valores %H:%M:%S
df_clean['create_date'] = pd.to_datetime(df_clean['create_date']).dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Convertirlo a formato datetime
df_clean['create_date'] = pd.to_datetime(df_clean['create_date'])

# %%
df_clean.dtypes
# Out:
# id                                      int64
# id_record_status                        int64
# id_company_variation                    int64
# id_product                              int64
# id_cat_autopart_make                  float64
# id_cat_autopart_model                 float64
# id_cat_autopart_engine_type           float64
# id_cat_autopart_engine_size           float64
# id_cat_autopart_notes                 float64
# id_subscription                         int64
# year_from                               int64
# create_date                    datetime64[ns]
# dtype: object

# %%
df_clean.isnull().sum()
# Out:
# id                                0
# id_record_status                  0
# id_company_variation              0
# id_product                        0
# id_cat_autopart_make            651
# id_cat_autopart_model           651
# id_cat_autopart_engine_type    5053
# id_cat_autopart_engine_size    5053
# id_cat_autopart_notes          5053
# id_subscription                   0
# year_from                         0
# create_date                       0
# dtype: int64

# %%
# Se sustituyen los valores faltantes por valores que no existen en las columnas en este caso se les da un valor de 0
df_clean['id_cat_autopart_notes'] = df_clean['id_cat_autopart_notes'].fillna(0)
df_clean['id_cat_autopart_engine_size'] = df_clean['id_cat_autopart_engine_size'].fillna(0)
df_clean['id_cat_autopart_engine_type'] = df_clean['id_cat_autopart_engine_type'].fillna(0)
df_clean['id_cat_autopart_model'] = df_clean['id_cat_autopart_model'].fillna(0)
df_clean['id_cat_autopart_make'] = df_clean['id_cat_autopart_make'].fillna(0)

# %%
df_clean.isnull().sum()
# Out:
# id                             0
# id_record_status               0
# id_company_variation           0
# id_product                     0
# id_cat_autopart_make           0
# id_cat_autopart_model          0
# id_cat_autopart_engine_type    0
# id_cat_autopart_engine_size    0
# id_cat_autopart_notes          0
# id_subscription                0
# year_from                      0
# create_date                    0
# dtype: int64

# %%
df_clean.dtypes
# Out:
# id                                      int64
# id_record_status                        int64
# id_company_variation                    int64
# id_product                              int64
# id_cat_autopart_make                  float64
# id_cat_autopart_model                 float64
# id_cat_autopart_engine_type           float64
# id_cat_autopart_engine_size           float64
# id_cat_autopart_notes                 float64
# id_subscription                         int64
# year_from                               int64
# create_date                    datetime64[ns]
# dtype: object
